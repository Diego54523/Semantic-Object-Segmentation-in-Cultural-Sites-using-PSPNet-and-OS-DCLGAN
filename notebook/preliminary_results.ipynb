# %% [markdown]
# Caso 0% dati reali usati, addestrato per 80 epoche.
#
# >>>> RISULTATI FINALI <<<<
#
#
# --- METRICHE IoU E ACCURACY UFFICIALI (Per Singola Classe) ---
#   Classe_0: IoU = 0.4893 | Accuracy = 0.6490
#   Classe_1: IoU = 0.0000 | Accuracy = 0.0000
#   Classe_2: IoU = 0.1537 | Accuracy = 0.2372
#   Classe_3: IoU = 0.1505 | Accuracy = 0.1973
#   Classe_4: IoU = 0.0088 | Accuracy = 0.0175
#   Classe_5: IoU = 0.1203 | Accuracy = 0.1892
#   Classe_6: IoU = 0.0000 | Accuracy = 0.0000
#   Classe_7: IoU = 0.0257 | Accuracy = 0.1223
#   Classe_8: IoU = 0.1906 | Accuracy = 0.3331
#   Classe_9: IoU = 0.2384 | Accuracy = 0.6230
#   Classe_10: IoU = 0.2088 | Accuracy = 0.2447
#   Classe_11: IoU = 0.5169 | Accuracy = 0.7368
#   Classe_12: IoU = 0.0078 | Accuracy = 0.0084
#   Classe_13: IoU = 0.1238 | Accuracy = 0.1646
#   Classe_14: IoU = 0.0933 | Accuracy = 0.1041
#   Classe_15: IoU = 0.0198 | Accuracy = 0.0267
#   Classe_16: IoU = 0.2080 | Accuracy = 0.3481
#   Classe_17: IoU = 0.0999 | Accuracy = 0.4480
#   Classe_18: IoU = 0.0462 | Accuracy = 0.1505
#   Classe_19: IoU = 0.2006 | Accuracy = 0.4044
#   Classe_20: IoU = 0.0000 | Accuracy = 0.0000
#   Classe_21: IoU = 0.0115 | Accuracy = 0.0147
#   Classe_22: IoU = 0.1342 | Accuracy = 0.2291
#   Classe_23: IoU = 0.1610 | Accuracy = 0.1948
#   Classe_24: IoU = 0.1941 | Accuracy = 0.2637
#
# --> mIoU Globale: 0.1361
# --> Mean Pixel Accuracy (mPA): 0.2283
# --> Overall Pixel Accuracy (PA): 0.5189
#
# --- CLASSIFICATION REPORT ---
#               precision    recall  f1-score   support
#
#     Classe_0     0.6654    0.6490    0.6571  31420475
#     Classe_1     0.0000    0.0000    0.0000         0
#     Classe_2     0.3040    0.2372    0.2665    651151
#     Classe_3     0.3883    0.1973    0.2617   1519265
#     Classe_4     0.0176    0.0175    0.0175     66421
#     Classe_5     0.2483    0.1892    0.2148    778683
#     Classe_6     0.0000    0.0000    0.0000         0
#     Classe_7     0.0315    0.1223    0.0501    174211
#     Classe_8     0.3083    0.3331    0.3202   1519485
#     Classe_9     0.2786    0.6230    0.3850   2377316
#    Classe_10     0.5873    0.2447    0.3454   1481135
#    Classe_11     0.6339    0.7368    0.6815   4133816
#    Classe_12     0.1011    0.0084    0.0155    460505
#    Classe_13     0.3328    0.1646    0.2203   1056010
#    Classe_14     0.4720    0.1041    0.1706   2136936
#    Classe_15     0.0716    0.0267    0.0389    616184
#    Classe_16     0.3407    0.3481    0.3443   1352138
#    Classe_17     0.1139    0.4480    0.1816    341280
#    Classe_18     0.0625    0.1505    0.0883    220326
#    Classe_19     0.2847    0.4044    0.3342   1516998
#    Classe_20     0.0000    0.0000    0.0000         0
#    Classe_21     0.0502    0.0147    0.0227    504196
#    Classe_22     0.2448    0.2291    0.2367   1284542
#    Classe_23     0.4809    0.1948    0.2773   1177589
#    Classe_24     0.4238    0.2637    0.3251    785866
#
#     accuracy                         0.5189  55574528
#    macro avg     0.2577    0.2283    0.2182  55574528
# weighted avg     0.5425    0.5189    0.5165  55574528

# %% [markdown]
# Caso con 100% dati reali, addestrato per 30 epoche, più 3 di warm-up
#
# =======================================================
# AVVIO EVALUATION FINALE SUL DATASET REALE
# =======================================================
#
# >>>> RISULTATI FINALI (MIXED REAL 100.0%) <<<<
#
# --- METRICHE IoU E ACCURACY UFFICIALI (Per Singola Classe) ---
#   Classe_0: IoU = 0.3789 | Accuracy = 0.4218
#   Classe_1: IoU = 0.0000 | Accuracy = 0.0000
#   Classe_2: IoU = 0.3397 | Accuracy = 0.7519
#   Classe_3: IoU = 0.4465 | Accuracy = 0.5878
#   Classe_4: IoU = 0.3358 | Accuracy = 0.3641
#   Classe_5: IoU = 0.2806 | Accuracy = 0.4057
#   Classe_6: IoU = 0.0000 | Accuracy = 0.0000
#   Classe_7: IoU = 0.1984 | Accuracy = 0.6556
#   Classe_8: IoU = 0.5259 | Accuracy = 0.7419
#   Classe_9: IoU = 0.3303 | Accuracy = 0.9255
#   Classe_10: IoU = 0.4925 | Accuracy = 0.7665
#   Classe_11: IoU = 0.5814 | Accuracy = 0.8569
#   Classe_12: IoU = 0.6516 | Accuracy = 0.9823
#   Classe_13: IoU = 0.6023 | Accuracy = 0.8822
#   Classe_14: IoU = 0.5807 | Accuracy = 0.6534
#   Classe_15: IoU = 0.0387 | Accuracy = 0.0389
#   Classe_16: IoU = 0.2629 | Accuracy = 0.3618
#   Classe_17: IoU = 0.4194 | Accuracy = 0.9830
#   Classe_18: IoU = 0.4468 | Accuracy = 0.8524
#   Classe_19: IoU = 0.2284 | Accuracy = 0.9897
#   Classe_20: IoU = 0.0000 | Accuracy = 0.0000
#   Classe_21: IoU = 0.5323 | Accuracy = 0.7204
#   Classe_22: IoU = 0.4031 | Accuracy = 0.7810
#   Classe_23: IoU = 0.6158 | Accuracy = 0.6906
#   Classe_24: IoU = 0.4677 | Accuracy = 0.9087
#
# --> mIoU Globale: 0.3664
# --> Mean Pixel Accuracy (mPA): 0.6129
# --> Overall Pixel Accuracy (PA): 0.5633
#
# --- CLASSIFICATION REPORT ---
#               precision    recall  f1-score   support
#
#     Classe_0     0.7887    0.4218    0.5496  31420475
#     Classe_1     0.0000    0.0000    0.0000         0
#     Classe_2     0.3826    0.7519    0.5072    651151
#     Classe_3     0.6501    0.5878    0.6174   1519265
#     Classe_4     0.8118    0.3641    0.5027     66421
#     Classe_5     0.4763    0.4057    0.4382    778683
#     Classe_6     0.0000    0.0000    0.0000         0
#     Classe_7     0.2214    0.6556    0.3311    174211
#     Classe_8     0.6437    0.7419    0.6893   1519485
#     Classe_9     0.3393    0.9255    0.4966   2377316
#    Classe_10     0.5795    0.7665    0.6600   1481135
#    Classe_11     0.6439    0.8569    0.7353   4133816
#    Classe_12     0.6593    0.9823    0.7890    460505
#    Classe_13     0.6550    0.8822    0.7518   1056010
#    Classe_14     0.8391    0.6534    0.7347   2136936
#    Classe_15     0.8873    0.0389    0.0745    616184
#    Classe_16     0.4902    0.3618    0.4163   1352138
#    Classe_17     0.4225    0.9830    0.5910    341280
#    Classe_18     0.4843    0.8524    0.6176    220326
#    Classe_19     0.2289    0.9897    0.3719   1516998
#    Classe_20     0.0000    0.0000    0.0000         0
#    Classe_21     0.6710    0.7204    0.6948    504196
#    Classe_22     0.4545    0.7810    0.5746   1284542
#    Classe_23     0.8503    0.6906    0.7622   1177589
#    Classe_24     0.4908    0.9087    0.6373    785866
#
#     accuracy                         0.5633  55574528
#    macro avg     0.5068    0.6129    0.5017  55574528
# weighted avg     0.6962    0.5633    0.5747  55574528
#
# === FINE ADDESTRAMENTO ===

# %% [markdown]
# Caso 50% real images.
#
# =======================================================
# AVVIO EVALUATION FINALE SUL DATASET REALE
# =======================================================
#
# >>>> RISULTATI FINALI (MIXED REAL 50.0%) <<<<
#
# --- METRICHE IoU E ACCURACY UFFICIALI (Per Singola Classe) ---
#   Classe_0: IoU = 0.4240 | Accuracy = 0.4771
#   Classe_1: IoU = 0.0000 | Accuracy = 0.0000
#   Classe_2: IoU = 0.3864 | Accuracy = 0.4775
#   Classe_3: IoU = 0.5209 | Accuracy = 0.7182
#   Classe_4: IoU = 0.3957 | Accuracy = 0.5422
#   Classe_5: IoU = 0.0577 | Accuracy = 0.0633
#   Classe_6: IoU = 0.0000 | Accuracy = 0.0000
#   Classe_7: IoU = 0.0095 | Accuracy = 0.0096
#   Classe_8: IoU = 0.4142 | Accuracy = 0.9013
#   Classe_9: IoU = 0.3118 | Accuracy = 0.9372
#   Classe_10: IoU = 0.5232 | Accuracy = 0.8232
#   Classe_11: IoU = 0.5785 | Accuracy = 0.9358
#   Classe_12: IoU = 0.5994 | Accuracy = 0.8813
#   Classe_13: IoU = 0.0000 | Accuracy = 0.0000
#   Classe_14: IoU = 0.7469 | Accuracy = 0.9110
#   Classe_15: IoU = 0.0081 | Accuracy = 0.0081
#   Classe_16: IoU = 0.2226 | Accuracy = 0.3150
#   Classe_17: IoU = 0.4198 | Accuracy = 0.7928
#   Classe_18: IoU = 0.3917 | Accuracy = 0.7785
#   Classe_19: IoU = 0.3143 | Accuracy = 0.9810
#   Classe_20: IoU = 0.0000 | Accuracy = 0.0000
#   Classe_21: IoU = 0.4607 | Accuracy = 0.5452
#   Classe_22: IoU = 0.3295 | Accuracy = 0.8303
#   Classe_23: IoU = 0.5137 | Accuracy = 0.6738
#   Classe_24: IoU = 0.4984 | Accuracy = 0.8995
#
# --> mIoU Globale: 0.3251
# --> Mean Pixel Accuracy (mPA): 0.5401
# --> Overall Pixel Accuracy (PA): 0.5888
#
# --- CLASSIFICATION REPORT ---
#               precision    recall  f1-score   support
#
#     Classe_0     0.7921    0.4771    0.5955  31420475
#     Classe_1     0.0000    0.0000    0.0000         0
#     Classe_2     0.6693    0.4775    0.5574    651151
#     Classe_3     0.6546    0.7182    0.6849   1519265
#     Classe_4     0.5942    0.5422    0.5670     66421
#     Classe_5     0.3954    0.0633    0.1091    778683
#     Classe_6     0.0000    0.0000    0.0000         0
#     Classe_7     0.4487    0.0096    0.0187    174211
#     Classe_8     0.4339    0.9013    0.5858   1519485
#     Classe_9     0.3184    0.9372    0.4754   2377316
#    Classe_10     0.5894    0.8232    0.6870   1481135
#    Classe_11     0.6024    0.9358    0.7330   4133816
#    Classe_12     0.6520    0.8813    0.7495    460505
#    Classe_13     0.0000    0.0000    0.0000   1056010
#    Classe_14     0.8057    0.9110    0.8551   2136936
#    Classe_15     0.8736    0.0081    0.0160    616184
#    Classe_16     0.4313    0.3150    0.3641   1352138
#    Classe_17     0.4715    0.7928    0.5913    341280
#    Classe_18     0.4408    0.7785    0.5629    220326
#    Classe_19     0.3163    0.9810    0.4783   1516998
#    Classe_20     0.0000    0.0000    0.0000         0
#    Classe_21     0.7481    0.5452    0.6308    504196
#    Classe_22     0.3533    0.8303    0.4957   1284542
#    Classe_23     0.6839    0.6738    0.6788   1177589
#    Classe_24     0.5278    0.8995    0.6653    785866
#
#     accuracy                         0.5888  55574528
#    macro avg     0.4721    0.5401    0.4441  55574528
# weighted avg     0.6740    0.5888    0.5814  55574528
#
# === FINE ADDESTRAMENTO ===

# %% [markdown]
# ======================================================================
#  VALUTAZIONE MODELLO: 0% Dati Reali
# ======================================================================
# Caricamento pesi da: weights/pspnet_final.pth...
# Pesi caricati con successo.
# Inizio inferenza sulle immagini...
#  - Elaborato batch 10/106
#  - Elaborato batch 20/106
#  - Elaborato batch 30/106
#  - Elaborato batch 40/106
#  - Elaborato batch 50/106
#  - Elaborato batch 60/106
#  - Elaborato batch 70/106
#  - Elaborato batch 80/106
#  - Elaborato batch 90/106
#  - Elaborato batch 100/106
#
# >>>> Risultati: <<<<
# --> Accuracy% (PA):        51.89%
# --> Class Accuracy% (mPA): 22.83%
# --> Mean IoU%:             13.61%
# --> FWAVACC%:              37.07%
#
# --- CLASSIFICATION REPORT (SKLEARN) ---
#               precision    recall  f1-score   support
#
#     Classe_0     0.6654    0.6490    0.6571  31420475
#     Classe_1     0.0000    0.0000    0.0000         0
#     Classe_2     0.3041    0.2372    0.2665    651151
#     Classe_3     0.3883    0.1973    0.2616   1519265
#     Classe_4     0.0176    0.0175    0.0175     66421
#     Classe_5     0.2483    0.1892    0.2148    778683
#     Classe_6     0.0000    0.0000    0.0000         0
#     Classe_7     0.0315    0.1223    0.0502    174211
#     Classe_8     0.3083    0.3331    0.3202   1519485
#     Classe_9     0.2786    0.6230    0.3850   2377316
#    Classe_10     0.5873    0.2447    0.3454   1481135
#    Classe_11     0.6339    0.7368    0.6815   4133816
#    Classe_12     0.1011    0.0084    0.0155    460505
#    Classe_13     0.3327    0.1646    0.2203   1056010
#    Classe_14     0.4720    0.1041    0.1706   2136936
#    Classe_15     0.0716    0.0267    0.0389    616184
#    Classe_16     0.3407    0.3481    0.3443   1352138
#    Classe_17     0.1139    0.4479    0.1816    341280
#    Classe_18     0.0625    0.1505    0.0883    220326
#    Classe_19     0.2847    0.4044    0.3342   1516998
#    Classe_20     0.0000    0.0000    0.0000         0
#    Classe_21     0.0502    0.0147    0.0227    504196
#    Classe_22     0.2448    0.2292    0.2367   1284542
#    Classe_23     0.4809    0.1948    0.2773   1177589
#    Classe_24     0.4238    0.2637    0.3251    785866
#
#     accuracy                         0.5189  55574528
#    macro avg     0.2577    0.2283    0.2182  55574528
# weighted avg     0.5425    0.5189    0.5165  55574528
#
#
# ======================================================================
#  VALUTAZIONE MODELLO: 50% Dati Reali
# ======================================================================
# Caricamento pesi da: weights/pspnet_epoch_30_real50.pth...
# Pesi caricati con successo.
# Inizio inferenza sulle immagini...
#  - Elaborato batch 10/106
#  - Elaborato batch 20/106
#  - Elaborato batch 30/106
#  - Elaborato batch 40/106
#  - Elaborato batch 50/106
#  - Elaborato batch 60/106
#  - Elaborato batch 70/106
#  - Elaborato batch 80/106
#  - Elaborato batch 90/106
#  - Elaborato batch 100/106
#
# >>>> Risultati: <<<<
# --> Accuracy% (PA):        58.88%
# --> Class Accuracy% (mPA): 54.01%
# --> Mean IoU%:             32.51%
# --> FWAVACC%:              42.31%
#
# --- CLASSIFICATION REPORT (SKLEARN) ---
#               precision    recall  f1-score   support
#
#     Classe_0     0.7921    0.4771    0.5955  31420475
#     Classe_1     0.0000    0.0000    0.0000         0
#     Classe_2     0.6693    0.4775    0.5574    651151
#     Classe_3     0.6546    0.7182    0.6849   1519265
#     Classe_4     0.5942    0.5422    0.5670     66421
#     Classe_5     0.3953    0.0633    0.1091    778683
#     Classe_6     0.0000    0.0000    0.0000         0
#     Classe_7     0.4490    0.0096    0.0187    174211
#     Classe_8     0.4339    0.9013    0.5858   1519485
#     Classe_9     0.3184    0.9372    0.4754   2377316
#    Classe_10     0.5895    0.8232    0.6870   1481135
#    Classe_11     0.6024    0.9358    0.7330   4133816
#    Classe_12     0.6520    0.8813    0.7495    460505
#    Classe_13     0.0000    0.0000    0.0000   1056010
#    Classe_14     0.8056    0.9110    0.8551   2136936
#    Classe_15     0.8739    0.0081    0.0160    616184
#    Classe_16     0.4313    0.3150    0.3641   1352138
#    Classe_17     0.4715    0.7927    0.5913    341280
#    Classe_18     0.4408    0.7785    0.5629    220326
#    Classe_19     0.3163    0.9810    0.4784   1516998
#    Classe_20     0.0000    0.0000    0.0000         0
#    Classe_21     0.7481    0.5452    0.6308    504196
#    Classe_22     0.3534    0.8303    0.4957   1284542
#    Classe_23     0.6838    0.6738    0.6787   1177589
#    Classe_24     0.5278    0.8995    0.6653    785866
#
#     accuracy                         0.5888  55574528
#    macro avg     0.4721    0.5401    0.4441  55574528
# weighted avg     0.6740    0.5888    0.5814  55574528
#
#
# ======================================================================
#  VALUTAZIONE MODELLO: 100% Dati Reali
# ======================================================================
# Caricamento pesi da: weights/pspnet_final_real100.pth...
# Pesi caricati con successo.
# Inizio inferenza sulle immagini...
#  - Elaborato batch 10/106
#  - Elaborato batch 20/106
#  - Elaborato batch 30/106
#  - Elaborato batch 40/106
#  - Elaborato batch 50/106
#  - Elaborato batch 60/106
#  - Elaborato batch 70/106
#  - Elaborato batch 80/106
#  - Elaborato batch 90/106
#  - Elaborato batch 100/106
#
# >>>> Risultati: <<<<
# --> Accuracy% (PA):        56.33%
# --> Class Accuracy% (mPA): 61.29%
# --> Mean IoU%:             36.64%
# --> FWAVACC%:              41.06%
#
# --- CLASSIFICATION REPORT (SKLEARN) ---
#               precision    recall  f1-score   support
#
#     Classe_0     0.7887    0.4218    0.5496  31420475
#     Classe_1     0.0000    0.0000    0.0000         0
#     Classe_2     0.3827    0.7518    0.5072    651151
#     Classe_3     0.6501    0.5878    0.6174   1519265
#     Classe_4     0.8118    0.3641    0.5027     66421
#     Classe_5     0.4763    0.4058    0.4382    778683
#     Classe_6     0.0000    0.0000    0.0000         0
#     Classe_7     0.2215    0.6556    0.3311    174211
#     Classe_8     0.6437    0.7419    0.6893   1519485
#     Classe_9     0.3393    0.9255    0.4966   2377316
#    Classe_10     0.5795    0.7664    0.6600   1481135
#    Classe_11     0.6439    0.8569    0.7353   4133816
#    Classe_12     0.6593    0.9824    0.7890    460505
#    Classe_13     0.6550    0.8822    0.7518   1056010
#    Classe_14     0.8391    0.6534    0.7347   2136936
#    Classe_15     0.8872    0.0389    0.0745    616184
#    Classe_16     0.4901    0.3618    0.4163   1352138
#    Classe_17     0.4225    0.9830    0.5909    341280
#    Classe_18     0.4842    0.8524    0.6176    220326
#    Classe_19     0.2289    0.9897    0.3718   1516998
#    Classe_20     0.0000    0.0000    0.0000         0
#    Classe_21     0.6710    0.7205    0.6948    504196
#    Classe_22     0.4545    0.7809    0.5746   1284542
#    Classe_23     0.8503    0.6906    0.7622   1177589
#    Classe_24     0.4908    0.9087    0.6373    785866
#
#     accuracy                         0.5633  55574528
#    macro avg     0.5068    0.6129    0.5017  55574528
# weighted avg     0.6962    0.5633    0.5747  55574528
#
# === FINE VALUTAZIONE ===
